# %%
import pandas as pd
import os

# %%
os.chdir("../")
os.chdir("../ML_Finance_Project_files/data/raw")
df = pd.read_csv("raw_data.csv")

# %%
print(f"Shape: {df.shape}")
print(f"Unique Tickers: {df['Ticker'].nunique()}")
# Out:
# Shape: (61780, 7)
# Unique Tickers: 25

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close     Volume Ticker
# 0  2015-01-02  27.847500  27.860001  26.837500  27.332500  212818400   AAPL
# 1  2015-01-05  27.072500  27.162500  26.352501  26.562500  257142000   AAPL
# 2  2015-01-06  26.635000  26.857500  26.157499  26.565001  263188400   AAPL
# 3  2015-01-07  26.799999  27.049999  26.674999  26.937500  160423600   AAPL
# 4  2015-01-08  27.307501  28.037500  27.174999  27.972500  237458000   AAPL

# %%
print(df.dtypes)
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# Ticker     object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Ticker    0
# dtype: int64

# %%
print(df['Ticker'].value_counts())
# Out:
# Ticker
# AAPL     2515
# MSFT     2515
# NVDA     2515
# GOOGL    2515
# AMZN     2515
# META     2515
# TSLA     2515
# JPM      2515
# GS       2515
# BAC      2515
# WFC      2515
# C        2515
# MS       2515
# SPY      2515
# QQQ      2515
# DIA      2515
# VTI      2515
# ARKK     2515
# XLF      2515
# XLK      2515
# INTC     2515
# AMD      2515
# CRM      2515
# ORCL     2515
# UBER     1420
# Name: count, dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_values(by=["Ticker", "Date"])

# %%
os.chdir("../")
df.to_csv("../ML_Finance_Project_files/data/processed/validated_data.csv")
